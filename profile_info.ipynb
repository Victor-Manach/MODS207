# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import json
import pandas as pd
import re
import csv

# %%
data = pd.DataFrame(columns=['name', 'image', 'description', 'location', 'speaking', 'rating', 'num_reviews', 'currency', 'salary', 'num_proj', 'num_buyers', 'last_active', 'expertise', 'skills', 'gender'])

# %%
profiles_url = np.array(pd.read_csv('./profiles_url.csv'))

# %%
profiles_url
# Out:
#        Unnamed: 0                                                url
# 0               0  https://www.peopleperhour.com/freelancer/writi...
# 1               1  https://www.peopleperhour.com/freelancer/writi...
# 2               2  https://www.peopleperhour.com/freelancer/writi...
# 3               3  https://www.peopleperhour.com/freelancer/writi...
# 4               4  https://www.peopleperhour.com/freelancer/writi...
# ...           ...                                                ...
# 10003       10003  https://www.peopleperhour.com/freelancer/al_sa...
# 10004       10004  https://www.peopleperhour.com/freelancer/writi...
# 10005       10005  https://www.peopleperhour.com/freelancer/socia...
# 10006       10006  https://www.peopleperhour.com/freelancer/marke...
# 10007       10007  https://www.peopleperhour.com/freelancer/writi...
#
# [10008 rows x 2 columns]

# %%
url_list = ['https://www.peopleperhour.com/freelancer/marketing-seo/gajura-constantin-seo-expert-and-experienced-guest-wwanwy',
            'https://www.peopleperhour.com/freelancer/writing-translation/logical_translation_localisation-translations-translation-localisation-mnyay',
            'https://www.peopleperhour.com/freelancer/writing-translation/karen-siddall-cv-linkedin-writer-for-the-legal-vjjjyvm',
            'https://www.peopleperhour.com/freelancer/writing-translation/michelle-vanwettere-1-professional-translator-on-pph-yznqxqy',
            'https://www.peopleperhour.com/freelancer/writing-translation/artisticpen-translation-voice-over-social-ywyjqw']

# %%
def guess_gender(rev: list) -> str:
    """
    Determine gender of a person with a list of reviews
    """
    genders = ['male', 'female']
    gender = None
    nb_male, nb_female = 0, 0
    male = ["he", "his", "him", "himself"]
    female = ["she", "her", "hers", "herself"]

    for r in rev:
        for word in male:
            if re.compile(r'\b({0})\b'.format(word), flags=re.IGNORECASE).search(r) is not None:
                nb_male+=1
        for word in female : 
            if re.compile(r'\b({0})\b'.format(word), flags=re.IGNORECASE).search(r) is not None:
                nb_female+=1
    if nb_male !=0 or nb_female!=0:
        prob_male, prob_female = nb_male/(nb_male+nb_female), nb_female/(nb_male+nb_female)
        if prob_male!=prob_female:
            gender = genders[np.argmax([prob_male, prob_female])]
    return gender

# %%
def get_profile_info(url: str, verbose:int =1) -> list:
    """
    Get the information available on the freelancer profile webpage
    """
    r = requests.get(url)
    soup = BeautifulSoup(r.content)

    location = soup.find("div", {"class": "member-location"}).get_text().replace('\n', '').replace('\r', '') if soup.find("div", {"class": "member-location"}) else ""
    speaking = soup.find("div", {"class": "member-languages clearfix"}).get_text().replace('\n', '').replace('\r', '') if soup.find("div", {"class": "member-languages clearfix"}) else ""
    rating = soup.find("div", {"class": "total-rating"}).get_text() if soup.find("div", {"class": "total-rating"}) else ""
    num_reviews = int(soup.find("div", {"class": "total-reviews"}).get_text().replace('(', '').replace(')', '')) if soup.find("div", {"class": "total-reviews"}) else ""
    cost = soup.find("span", {"class": "member-cost"}).get_text().replace('\n', '').replace('\r', '') if soup.find("span", {"class": "member-cost"}) else ""
    currency = cost[0] if cost else ""
    salary = int(cost[1:].replace('/hr', '')) if cost else ""
    num_proj = int(re.sub("[^0-9]", "", soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memStats-container']).find("div", {"class": "memberStats-item memberStats-rating"}).get_text().replace('\r', '').replace('\n', ''))) if soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memStats-container']).find("div", {"class": "memberStats-item memberStats-rating"}) else ""
    num_buyers = int(re.sub("[^0-9]", "", soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memStats-container']).find("div", {"class": "memberStats-item u-mgb--1"}).get_text().replace('\r', '').replace('\n', ''))) if soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memStats-container']).find("div", {"class": "memberStats-item u-mgb--1"}) else ""
    last_active = soup.find("div", {"class": "memberStats-item item-margin"}).find("div", {"class": "insights-value"}).get_text().replace('\n', '').replace('\r', '') if soup.find("div", {"class": "memberStats-item item-margin"}).find("div", {"class": "insights-value"}) else ""
    expertise = soup.find("div", {"class": "clearfix industry-expertise-list skills-item"}).get_text().replace('\n', '').replace('\r', '') if soup.find("div", {"class": "clearfix industry-expertise-list skills-item"}) else ""
    response_time = soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memberStats-item']).find("div", {"class": "insights-value"}).get_text().replace('\n', '').replace('\r', '') if soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['memberStats-item']).find("div", {"class": "insights-value"}) else ""
    skills = soup.find("div", {"class": "col-md-12 col-lg-12"}).get_text().replace('\n', '').replace('\r', '') if soup.find("div", {"class": "col-md-12 col-lg-12"}) else ""

    profile = json.loads("".join(soup.find("script", {"type":"application/ld+json"}).contents)) if soup.find("script", {"type":"application/ld+json"}) else ""
    name = profile['name'].replace('\n', '').replace('\r', '') if profile['name'] else ""
    image = profile['image'].replace('\n', '').replace('\r', '') if profile['image'] else ""
    description = profile['description'].replace('\n', '').replace('\r', '').replace('\t', '') if profile['description'] else ""

    reviews = [com.find("p").get_text() for com in soup.findAll("li", {"class": "item participant feedback clearfix"})] if soup.findAll("li", {"class": "item participant feedback clearfix"}) else ""
    gender = guess_gender(reviews) if reviews else None
    info = [name, image, description, location, speaking, rating, num_reviews,currency, salary, num_proj, num_buyers, last_active, expertise,skills, gender]
    return info

# %%
data = pd.DataFrame(columns=['name', 'image', 'description', 'location', 'speaking', 'rating', 'num_reviews', 'currency', 'salary', 'num_proj', 'num_buyers', 'last_active', 'expertise', 'skills', 'gender'])

for url in profiles[:20]:
    info = get_profile_info(url)
    series = pd.Series(info, index = data.columns)
    data = data.append(series, ignore_index=True)

# %%
data
# Out:
#                                                  name  \
# 0                                     Hannah Hutchins
# 1                                    Translate Guru .
# 2                  Logical Translation & Localisation
# 3                                              Al Nas
# 4                                       Karen Siddall
# 5                                 Michelle Vanwettere
# 6                                         ArtisticPen
# 7                                       Dina Lourenço
# 8                                   Donene Diedericks
# 9   Fast Translations and Multilanguage Solutions ...
# 10                                       Loreta Saddi
# 11                                    Rosalinda Fiore
# 12                                           Jodie P.
# 13                                Caterina Piagentini
# 14                                        Fosca Colli
# 15                            Flavia Caselli Musumeci
# 16                                  Daniele D'Alessio
# 17                                       Manfred Wahl
# 18                                           Zahra R.
# 19                                              Zak A
#
#                                                 image  \
# 0   https://dw3i9sxi97owk.cloudfront.net/uploads/6...
# 1   https://dw3i9sxi97owk.cloudfront.net/uploads/b...
# 2   https://dw3i9sxi97owk.cloudfront.net/uploads/3...
# 3   https://dw3i9sxi97owk.cloudfront.net/uploads/0...
# 4   https://dw3i9sxi97owk.cloudfront.net/uploads/4...
# 5   https://dw3i9sxi97owk.cloudfront.net/uploads/9...
# 6   https://dw3i9sxi97owk.cloudfront.net/uploads/c...
# 7   https://dw3i9sxi97owk.cloudfront.net/uploads/2...
# 8   https://dw3i9sxi97owk.cloudfront.net/uploads/1...
# 9   https://dw3i9sxi97owk.cloudfront.net/uploads/6...
# 10  https://dw3i9sxi97owk.cloudfront.net/uploads/9...
# 11  https://dw3i9sxi97owk.cloudfront.net/uploads/d...
# 12  https://dw3i9sxi97owk.cloudfront.net/uploads/e...
# 13  https://dw3i9sxi97owk.cloudfront.net/uploads/c...
# 14  https://dw3i9sxi97owk.cloudfront.net/uploads/a...
# 15  https://dw3i9sxi97owk.cloudfront.net/uploads/8...
# 16  https://dw3i9sxi97owk.cloudfront.net/uploads/d...
# 17  https://dw3i9sxi97owk.cloudfront.net/uploads/2...
# 18  https://dw3i9sxi97owk.cloudfront.net/uploads/2...
# 19  https://dw3i9sxi97owk.cloudfront.net/uploads/c...
#
#                                           description  \
# 0   I am an audio transcriptionist with over four ...
# 1   Hello! Hola! Ciao! Bonjour! 你好!I do high-quali...
# 2   OFFERING A WIDE RANGE OF TRANSLATION SERVICESA...
# 3   QUALITY, SPEED and COMMUNICATION: These are th...
# 4   As an ex lawyer and experienced legal recruite...
# 5   I am a native Dutch, German and English speake...
# 6   We believe that Translation & Writing is an "A...
# 7   Hi,I'm a Portuguese (native speaker) freelance...
# 8   I am a native English professional, who is als...
# 9   Quality Translation:FTMLS is a leading provide...
# 10  I am Loreta Saddi. I am an experienced Transla...
# 11  Thank you for visiting my profile! Are you loo...
# 12  I've been working for the NHS as an administra...
# 13  DON'T PUT YOUR BUSINESS AT RISK: Choose a huma...
# 14  I'm a Top User - Italian translator, talian wr...
# 15  I am very passionate about different cultures ...
# 16  Hey! My name is Daniele but you can call me Da...
# 17  Freelancer for the last 23 year.Area Covered: ...
# 18  Services:Translation in various languagesAcade...
# 19  Whether its juicy, attention grabbing content,...
#
#                           location  \
# 0         Coventry, United Kingdom
# 1                 Cannanore, India
# 2   City of London, United Kingdom
# 3    Ystrad Mynach, United Kingdom
# 4       Warrington, United Kingdom
# 5             Hoogstraten, Belgium
# 6                    Mumbai, India
# 7                  Serta, Portugal
# 8           Pretoria, South Africa
# 9                   Gwalior, India
# 10  Los Angeles, CA, United States
# 11   Ystrad Mynach, United Kingdom
# 12           Derby, United Kingdom
# 13                     Pisa, Italy
# 14                     Rome, Italy
# 15          London, United Kingdom
# 16          Hendon, United Kingdom
# 17             Osnabrueck, Germany
# 18               Karachi, Pakistan
# 19  City of London, United Kingdom
#
#                                              speaking rating num_reviews  \
# 0                                    English speaking    5.0          24
# 1                                                        4.9         597
# 2       English, Spanish, French and Italian speaking    4.9         135
# 3   German, English, Spanish, French, Italian, Dut...    4.9         553
# 4                                    English speaking
# 5          German, English, French and Dutch speaking    5.0         198
# 6   German, Spanish, French, Italian, Dutch and Ru...    4.9          92
# 7                                    English speaking    5.0         273
# 8                      Afrikaans and English speaking    5.0          27
# 9                                    English speaking    4.7         111
# 10  English, Spanish, Italian and Portuguese speaking    5.0          94
# 11  English, Spanish, Italian and Portuguese speaking    4.9          45
# 12                                   English speaking    5.0          52
# 13  English, Spanish, Italian and Portuguese speaking    5.0         354
# 14                                                       5.0         350
# 15  English, Spanish, French, Italian and Portugue...    5.0          66
# 16               English, Italian and Polish speaking    5.0          13
# 17  German, English, Spanish, French and Portugues...    5.0          80
# 18  German, English, Spanish, French, Italian, Dut...    5.0          33
# 19                                   English speaking    4.8         669
#
#    currency salary num_proj num_buyers  \
# 0         £     10       24         17
# 1         $     20      720        375
# 2         £     20      140        100
# 3         £     16      404        292
# 4         £     75        1          1
# 5         €     40      134         91
# 6         £     25       70         55
# 7         €     15      205        136
# 8         $     25       26         19
# 9         £     15      171         94
# 10        $     15       75         58
# 11        €     20       45         40
# 12        £     15       32         18
# 13        €     15      277        177
# 14        €     10      249        156
# 15        £     15       50         40
# 16        £     10       14         12
# 17        €     20       65         52
# 18        $     18       31          9
# 19        £     20     1102        852
#
#                                 last_active  \
# 0                   Apr 22 2021
# 1                   Apr 22 2021
# 2                   Apr 22 2021
# 3                   Apr 22 2021
# 4                   Oct 25 2020
# 5                   Apr 22 2021
# 6                   Apr 21 2021
# 7                   Apr 22 2021
# 8                   Apr 22 2021
# 9                   Apr 22 2021
# 10                  Apr 22 2021
# 11                  Apr 22 2021
# 12                  Apr 22 2021
# 13                  Apr 22 2021
# 14                  Apr 22 2021
# 15                  Apr 22 2021
# 16                  Apr 18 2021
# 17                  Apr 22 2021
# 18                  Oct 01 2020
# 19                  Mar 17 2021
#
#                                             expertise  \
# 0           Industry expertise: Healthcare, Legal ...
# 1
# 2           Industry expertise: Advertising, Aeros...
# 3           Industry expertise: Advertising, Educa...
# 4           Industry expertise: Human Resources, L...
# 5           Industry expertise: Advertising, Legal...
# 6
# 7
# 8           Industry expertise: Education, Media a...
# 9           Industry expertise: Advertising, Aeros...
# 10          Industry expertise: Broadcasting, Fina...
# 11
# 12                        Industry expertise: Art
# 13
# 14
# 15
# 16          Industry expertise: Food, Healthcare, ...
# 17          Industry expertise: Aerospace, Automot...
# 18
# 19
#
#                                                skills  gender
# 0   Skillstranscriptioncopy typingaudio/sound tran...  female
# 1   SkillsGerman <=> English translationArabic <=>...    None
# 2   SkillseditingproofreadingGerman translationEng...  female
# 3   SkillstranscriptionGerman <=> English translat...    None
# 4   Skillslinkedin page designbusiness development...    None
# 5   Skillssocial media managementGerman <=> Englis...  female
# 6   SkillsGerman <=> English translationGerman tra...    None
# 7   Skillseditingmicrosoft exceloffice managementp...  female
# 8   Skillseditingproofreadinginternet researcharti...  female
# 9   SkillsFrench <=> English translationNorwegian ...    None
# 10  SkillsproofreadingEnglish translationItalian t...  female
# 11  SkillsItalian <=> English translationPortugues...  female
# 12  Skillsproofreadingcontent writingcreative writ...  female
# 13  Skillstranscriptionvirtual assistantonline mar...  female
# 14  Skillslink buildingarticleCopywritingblog writ...  female
# 15  SkillstranscriptionEnglish interpretationEngli...
# 16  Skillsacademic writingbusiness writingcontent ...    male
# 17  SkillsGerman <=> English translationsales lett...    male
# 18  Skillstranscriptionlogoacademic writingCopywri...  female
# 19  Skillsproofreadingacademic writingarticlebusin...    male

# %%
data.to_csv('./database.csv', index=False)
