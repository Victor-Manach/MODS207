# %%
import utils
import numpy as np
import pandas as pd

# %%
profile_urls = pd.read_csv('./profiles_url.csv')
profile_urls = np.array(profile_urls.url)

# %%
def scraping_profiles(urls: np.ndarray, verbose: int=1):
    columns = ['name', 'location', 'languages', 'description', 'rating', 'nb_reviews', 'price', 'skills', 'expertise', 'nb_projects', 'nb_buyers', 'last_active', 'gender']
    data = pd.DataFrame(columns=columns)
    for i, url in enumerate(urls):
        info = utils.profile_info(url)
        data = data.append(info, ignore_index=True)
        if verbose:
            if i%1000==0:
                print('{} profiles scraped'.format(i))
                print('**********************')
    print('End of scraping...')
    return data

# %%
data = scraping_profiles(profile_urls)
# Out:
# 0 profiles scraped
# **********************
# 1000 profiles scraped
# **********************
# 2000 profiles scraped
# **********************
# 3000 profiles scraped
# **********************
# 4000 profiles scraped
# **********************
# 5000 profiles scraped
# **********************
# 6000 profiles scraped
# **********************
# 7000 profiles scraped
# **********************
# 8000 profiles scraped
# **********************
# 9000 profiles scraped
# **********************
# 10000 profiles scraped
# **********************
# End of scraping...

# %%
data.shape
# Out:
# (10003, 13)

# %%
data
# Out:
#                                      name                        location  \
# 0                                Maria H.       Sheffield, United Kingdom
# 1                         Cormac Reynolds  City of London, United Kingdom
# 2                           Denise Toepel                 Cuenca, Ecuador
# 3                        Translate Guru .                Cannanore, India
# 4      Logical Translation & Localisation  City of London, United Kingdom
# ...                                   ...                             ...
# 9998                  Goggle Software Ltd           Leeds, United Kingdom
# 9999                    Roshan Rupasinghe              Colombo, Sri Lanka
# 10000                       Sally Lavinia                  Nairobi, Kenya
# 10001                     Mohammed Younes                Zgharta, Lebanon
# 10002                         Django Keur          Amsterdam, Netherlands
#
#                                            languages  \
# 0                                   English speaking
# 1                                   English speaking
# 2               English, Spanish and French speaking
# 3
# 4      English, Spanish, French and Italian speaking
# ...                                              ...
# 9998                                English speaking
# 9999                                English speaking
# 10000   English and Swahili (macrolanguage) speaking
# 10001                    Arabic and English speaking
# 10002                     English and Dutch speaking
#
#                                              description  rating nb_reviews  \
# 0      We are a small UK based company speciaIising i...     4.9       4694
# 1      Looking for a link building solution or some g...     5.0       1190
# 2      I am a Translation Specialist.  I work in publ...     0.0          0
# 3      Hello! Hola! Ciao! Bonjour! 你好!\r\n\r\nI do hi...     4.9        598
# 4      OFFERING A WIDE RANGE OF TRANSLATION SERVICES\...     4.9        135
# ...                                                  ...     ...        ...
# 9998   Goggle Software build CRMs and bespoke portals...     5.0         31
# 9999   I am an IIBA certified business analyst with 3...     0.0          0
# 10000                                                        0.0          0
# 10001  With a couple of years of experience, I was ab...     0.0          0
# 10002  Dear Sir/Madam, my name is Django. I am 16 yea...     0.0          0
#
#       price                                             skills  \
# 0       £25  [animation, graphics design, brand design, log...
# 1      £100  [online marketing, link building, marketing wr...
# 2       £20  [English translation, French <=> English, onli...
# 3       $20  [German <=> English translation, Arabic <=> En...
# 4       £20  [editing, proofreading, German translation, En...
# ...     ...                                                ...
# 9998    £50  [ajax, database development, hosting developme...
# 9999    $12  [business analysis, business writing, business...
# 10000   $30  [microsoft excel, proofreading, academic writi...
# 10001   $15  [graphics design, social media management, slo...
# 10002    €7  [Copywriting, creative writing, copy editing, ...
#
#                                                expertise nb_projects  \
# 0      Industry expertise: IT, Internet, Marketing, M...        7672
# 1                                                               1085
# 2      Industry expertise: Education and Telecommunic...           0
# 3                                                                721
# 4      Industry expertise: Advertising, Aerospace, Au...         140
# ...                                                  ...         ...
# 9998   Industry expertise: Electronics, IT and Techno...          26
# 9999                              Industry expertise: IT           0
# 10000  Industry expertise: Financial Services, Intern...           0
# 10001  Industry expertise: Advertising, Food, Media a...           0
# 10002                          Industry expertise: Sales           0
#
#       nb_buyers  last_active  gender
# 0          4168  Apr 26 2021  female
# 1           533  Apr 25 2021    None
# 2             0  Apr 25 2021    None
# 3           376  Apr 26 2021    None
# 4           100  Apr 24 2021    None
# ...         ...          ...     ...
# 9998         22  Apr 15 2021    male
# 9999          0  Dec 02 2020    None
# 10000         0  Dec 30 2020    None
# 10001         0  Apr 25 2021    None
# 10002         0  Jan 10 2021    None
#
# [10003 rows x 13 columns]

# %%
data.to_csv('./profiles_info.csv', index=False)

# %%
gender = data.gender
perc = (len(gender[gender=='male']) + len(gender[gender=='female']))/len(gender)*100
'Percentage of profiles where we have determined the gender {}%'.format(round(perc, 2))
# Out:
# 'Percentage of profiles where we have determined the gender 43.75%'
