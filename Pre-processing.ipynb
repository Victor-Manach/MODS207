# %%
import numpy as np
import pandas as pd
import datetime
import re
import ast
from nltk.corpus import stopwords
import utils
from collections import Counter

# %%
scraping_date = '_17_05_2021'
# data = pd.read_csv('./data/improved_profiles'+scraping_date+'.csv')
data = pd.read_csv('./data/profiles_info'+scraping_date+'.csv')

# %%
# fscraping_date = '2021-04-26'
fscraping_date = '2021-05-17'

# %% [markdown]
# # Format the price
#
# **Change all currencies to USD, using the exchange rate of the day when the data was scraped.**

# %%
currency_dict = {'£': 'GBP', '€': 'EUR', '$': 'USD'}
currencies = ['GBP', 'EUR']
exchange_rates = utils.get_exchange_rates(currencies, fscraping_date)

# %%
exchange_rates
# Out:
# {'GBP': 1.4084556052, 'EUR': 1.2143}

# %%
prices = np.array(data.price)
formated_prices = []

# %%
for i,price in enumerate(prices):
    currency, formated_price = price[0], float(price[1:])
    formated_currency = currency_dict[currency]
    if formated_currency != 'USD':
        exchange_rate = exchange_rates[formated_currency]
        converted_price = formated_price * exchange_rate
    else:
        converted_price = formated_price
    
    formated_prices.append(round(converted_price,2))

# %%
data = data.assign(price=formated_prices)
data = data.rename(columns={'price':'Price/hour in USD'})

# %% [markdown]
# # Split location in city and country
#
# **Location is always in the format city, country.**

# %%
location = np.array(data.location)

# %%
cities, countries = [], []
for city_country in location:
    splitted_location = city_country.split(',')
    if len(splitted_location)==2:
        city, country = city_country.split(',')
    elif splitted_location[2]=='United States':
        city, country = splitted_location[0], splitted_location[2]
    cities.append(city)
    countries.append(country)

# %%
data['city'] = cities
data['country'] = countries
data = data.drop('location', axis=1)

# %% [markdown]
# # Format gender
#
# **Assign** ``Unknown`` **to gender when the gender cannot be determined (when it is a company or a group of people.**

# %%
data = data.replace({'gender': {None: 'unknown'}})

# %% [markdown]
# # Format the last active date

# %%
last_active = np.array(data.last_active)
dates = []

# %%
for date in last_active:
    date_obj = datetime.datetime.strptime(date, '%b %d %Y')
    formated_date = date_obj.strftime('%d-%m-%Y')
    dates.append(formated_date)

# %%
data = data.assign(last_active=dates)

# %% [markdown]
# # Format languages spoken
#
# **Remove useless words and keep only the one referring to a language spoken by the person.**

# %%
languages = np.array(data.languages)
formated_languages = []

# %%
def remove_punc_stop_words(sentence: str) -> str:
    sentence = re.sub(pattern="[^\w\s]", repl="", string=sentence)
    sentence = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*').sub('', sentence)
    return sentence

# %%
# remove punctuation, stop words and the words speaking and macrolanguage
for spoken_languages in languages:
    if spoken_languages!=spoken_languages:
        formated_languages.append([])
        continue
    spoken_languages = remove_punc_stop_words(spoken_languages)
    speaking = re.compile(r'\bspeaking\b\s*' + r'|' + r'\bmacrolanguage\b\s*')
    spaces = re.compile(r'\s$')
    spoken_languages = spaces.sub('', speaking.sub('', spoken_languages))
    spoken_languages = spoken_languages.split(' ')
    formated_languages.append(spoken_languages)

# %%
data = data.assign(languages=formated_languages)

# %%
data
# Out:
#                                      name  \
# 0                                Maria H.
# 1                         Jessica O'Neill
# 2                           Scott Anfield
# 3                        Translate Guru .
# 4      Logical Translation & Localisation
# ...                                   ...
# 9998                        Kendra Aquino
# 9999                         Maria Jussel
# 10000                      Alex Halfacree
# 10001                      Allison Gerena
# 10002                        Bilal Alagha
#
#                                  languages  \
# 0                                [English]
# 1                                [English]
# 2                                [English]
# 3                                       []
# 4      [English, Spanish, French, Italian]
# ...                                    ...
# 9998                             [English]
# 9999                     [German, English]
# 10000                            [English]
# 10001                            [English]
# 10002  [Arabic, English, Spanish, Turkish]
#
#                                              description  rating  nb_reviews  \
# 0      We are a small UK based company speciaIising i...     4.9        4745
# 1      Your blog content and website copy need to be ...     5.0        1220
# 2      An experienced and professional writer based i...     4.9        1755
# 3      Hello! Hola! Ciao! Bonjour! 你好!\r\n\r\nI do hi...     4.9         608
# 4      OFFERING A WIDE RANGE OF TRANSLATION SERVICES\...     4.9         135
# ...                                                  ...     ...         ...
# 9998   I am an ambitious professional with working ba...     0.0           0
# 9999   Founding my business in 2020 has been a real s...     5.0           3
# 10000  Hi! My name is Alex and I am a 19 year old bus...     0.0           0
# 10001  I am a professional copywriter with a BA in En...     0.0           0
# 10002  Your job's been accomplished! – You've got my ...     0.0           0
#
#        Price/hour in USD                                             skills  \
# 0                  35.21  ['animation', 'graphics design', 'brand design...
# 1                  77.47  ['editing', 'proofreading', 'transcription', '...
# 2                  21.13  ['article', 'product description', 'content wr...
# 3                  20.00  ['German <=> English translation', 'Arabic <=>...
# 4                  28.17  ['editing', 'proofreading', 'German translatio...
# ...                  ...                                                ...
# 9998               20.00  ['editing', 'microsoft excel', 'proofreading',...
# 9999              145.72  ['financial accounting', 'financial management...
# 10000               8.45  ['administration support', 'data entry', 'busi...
# 10001              21.13  ['proofreading', 'email marketing', 'product d...
# 10002              17.00  ['social media management', 'content writing',...
#
#                                                expertise  nb_projects  \
# 0      Industry expertise: IT, Internet, Marketing, M...         7727
# 1               Industry expertise: PR, Sales and Travel         1546
# 2      Industry expertise: Advertising, Education, Ma...         1784
# 3                                                    NaN          730
# 4      Industry expertise: Advertising, Aerospace, Au...          140
# ...                                                  ...          ...
# 9998   Industry expertise: Advertising, Marketing and...            0
# 9999   Industry expertise: Financial Services, Human ...            2
# 10000                                                NaN            0
# 10001  Industry expertise: Gaming, Internet, Leisure,...            0
# 10002  Industry expertise: Education, IT, Internet, T...            0
#
#        nb_buyers last_active   gender            city          country
# 0           4204  17-05-2021  unknown       Sheffield   United Kingdom
# 1            880  17-05-2021  unknown  City of London   United Kingdom
# 2           1094  17-05-2021  unknown       Doncaster   United Kingdom
# 3            378  17-05-2021  unknown       Cannanore            India
# 4            100  17-05-2021  unknown  City of London   United Kingdom
# ...          ...         ...      ...             ...              ...
# 9998           0  14-02-2021  unknown       Viareggio            Italy
# 9999           1  24-04-2021  unknown          Vienna          Austria
# 10000          0  18-04-2021  unknown         Crawley   United Kingdom
# 10001          0  14-04-2021  unknown         Crawley   United Kingdom
# 10002          0  02-12-2020  unknown         Crawley   United Kingdom
#
# [10003 rows x 14 columns]

# %% [markdown]
# # Format the expertise

# %%
expertise = np.array(data.expertise)
formated_expertise = []

# %%
for profile_expertise in expertise:
    if profile_expertise!=profile_expertise:
        formated_expertise.append([])
        continue
    fexpertise = remove_punc_stop_words(profile_expertise)
    fexpertise = fexpertise.split(' ')[2:]
    formated_expertise.append(fexpertise)

# %%
data = data.assign(expertise=formated_expertise)
data = data.rename(columns={'expertise':'industry_expertise'})

# %%
data
# Out:
#                                      name  \
# 0                                Maria H.
# 1                         Jessica O'Neill
# 2                           Scott Anfield
# 3                        Translate Guru .
# 4      Logical Translation & Localisation
# ...                                   ...
# 9998                        Kendra Aquino
# 9999                         Maria Jussel
# 10000                      Alex Halfacree
# 10001                      Allison Gerena
# 10002                        Bilal Alagha
#
#                                  languages  \
# 0                                [English]
# 1                                [English]
# 2                                [English]
# 3                                       []
# 4      [English, Spanish, French, Italian]
# ...                                    ...
# 9998                             [English]
# 9999                     [German, English]
# 10000                            [English]
# 10001                            [English]
# 10002  [Arabic, English, Spanish, Turkish]
#
#                                              description  rating  nb_reviews  \
# 0      We are a small UK based company speciaIising i...     4.9        4745
# 1      Your blog content and website copy need to be ...     5.0        1220
# 2      An experienced and professional writer based i...     4.9        1755
# 3      Hello! Hola! Ciao! Bonjour! 你好!\r\n\r\nI do hi...     4.9         608
# 4      OFFERING A WIDE RANGE OF TRANSLATION SERVICES\...     4.9         135
# ...                                                  ...     ...         ...
# 9998   I am an ambitious professional with working ba...     0.0           0
# 9999   Founding my business in 2020 has been a real s...     5.0           3
# 10000  Hi! My name is Alex and I am a 19 year old bus...     0.0           0
# 10001  I am a professional copywriter with a BA in En...     0.0           0
# 10002  Your job's been accomplished! – You've got my ...     0.0           0
#
#        Price/hour in USD                                             skills  \
# 0                  35.21  ['animation', 'graphics design', 'brand design...
# 1                  77.47  ['editing', 'proofreading', 'transcription', '...
# 2                  21.13  ['article', 'product description', 'content wr...
# 3                  20.00  ['German <=> English translation', 'Arabic <=>...
# 4                  28.17  ['editing', 'proofreading', 'German translatio...
# ...                  ...                                                ...
# 9998               20.00  ['editing', 'microsoft excel', 'proofreading',...
# 9999              145.72  ['financial accounting', 'financial management...
# 10000               8.45  ['administration support', 'data entry', 'busi...
# 10001              21.13  ['proofreading', 'email marketing', 'product d...
# 10002              17.00  ['social media management', 'content writing',...
#
#                                       industry_expertise  nb_projects  \
# 0           [IT, Internet, Marketing, Media, Technology]         7727
# 1                                    [PR, Sales, Travel]         1546
# 2      [Advertising, Education, Marketing, Sales, Tra...         1784
# 3                                                     []          730
# 4      [Advertising, Aerospace, Automotive, Construct...          140
# ...                                                  ...          ...
# 9998                [Advertising, Marketing, Publishing]            0
# 9999   [Financial, Services, Human, Resources, IT, Ma...            2
# 10000                                                 []            0
# 10001  [Gaming, Internet, Leisure, Marketing, Telecom...            0
# 10002  [Education, IT, Internet, Technology, Telecomm...            0
#
#        nb_buyers last_active   gender            city          country
# 0           4204  17-05-2021  unknown       Sheffield   United Kingdom
# 1            880  17-05-2021  unknown  City of London   United Kingdom
# 2           1094  17-05-2021  unknown       Doncaster   United Kingdom
# 3            378  17-05-2021  unknown       Cannanore            India
# 4            100  17-05-2021  unknown  City of London   United Kingdom
# ...          ...         ...      ...             ...              ...
# 9998           0  14-02-2021  unknown       Viareggio            Italy
# 9999           1  24-04-2021  unknown          Vienna          Austria
# 10000          0  18-04-2021  unknown         Crawley   United Kingdom
# 10001          0  14-04-2021  unknown         Crawley   United Kingdom
# 10002          0  02-12-2020  unknown         Crawley   United Kingdom
#
# [10003 rows x 14 columns]

# %% [markdown]
# # Format the skills

# %%
def clean(skills: list) -> list:
    cleaned_skills = []
    for skill in skills:
        skill = skill.lower()
        REMOVE_PUNCT = re.compile("[.;:!\'?,\"()\[\]]")
        skill = re.sub(r"\([^()]*\)", "", skill)
        skill = REMOVE_PUNCT.sub("", skill)
        REPLACE_HTML = re.compile("<=>")
        skill = REPLACE_HTML.sub("", skill)
        skill = skill.strip()
        cleaned_skills.append(skill)
    return cleaned_skills

# %%
skills = np.array(data.skills)
formated_skills = []

# %%
for profile_skills in skills:
    profile_skills = ast.literal_eval(profile_skills)
    profile_skills = clean(profile_skills)
    formated_skills.append(profile_skills)

# %%
data = data.assign(skills=formated_skills)

# %%
data
# Out:
#                                      name  \
# 0                                Maria H.
# 1                         Jessica O'Neill
# 2                           Scott Anfield
# 3                        Translate Guru .
# 4      Logical Translation & Localisation
# ...                                   ...
# 9998                        Kendra Aquino
# 9999                         Maria Jussel
# 10000                      Alex Halfacree
# 10001                      Allison Gerena
# 10002                        Bilal Alagha
#
#                                  languages  \
# 0                                [English]
# 1                                [English]
# 2                                [English]
# 3                                       []
# 4      [English, Spanish, French, Italian]
# ...                                    ...
# 9998                             [English]
# 9999                     [German, English]
# 10000                            [English]
# 10001                            [English]
# 10002  [Arabic, English, Spanish, Turkish]
#
#                                              description  rating  nb_reviews  \
# 0      We are a small UK based company speciaIising i...     4.9        4745
# 1      Your blog content and website copy need to be ...     5.0        1220
# 2      An experienced and professional writer based i...     4.9        1755
# 3      Hello! Hola! Ciao! Bonjour! 你好!\r\n\r\nI do hi...     4.9         608
# 4      OFFERING A WIDE RANGE OF TRANSLATION SERVICES\...     4.9         135
# ...                                                  ...     ...         ...
# 9998   I am an ambitious professional with working ba...     0.0           0
# 9999   Founding my business in 2020 has been a real s...     5.0           3
# 10000  Hi! My name is Alex and I am a 19 year old bus...     0.0           0
# 10001  I am a professional copywriter with a BA in En...     0.0           0
# 10002  Your job's been accomplished! – You've got my ...     0.0           0
#
#        Price/hour in USD                                             skills  \
# 0                  35.21  [animation, graphics design, brand design, log...
# 1                  77.47  [editing, proofreading, transcription, academi...
# 2                  21.13  [article, product description, content writing...
# 3                  20.00  [german  english translation, arabic  english ...
# 4                  28.17  [editing, proofreading, german translation, en...
# ...                  ...                                                ...
# 9998               20.00  [editing, microsoft excel, proofreading, socia...
# 9999              145.72  [financial accounting, financial management, b...
# 10000               8.45  [administration support, data entry, business ...
# 10001              21.13  [proofreading, email marketing, product descri...
# 10002              17.00  [social media management, content writing, tec...
#
#                                       industry_expertise  nb_projects  \
# 0           [IT, Internet, Marketing, Media, Technology]         7727
# 1                                    [PR, Sales, Travel]         1546
# 2      [Advertising, Education, Marketing, Sales, Tra...         1784
# 3                                                     []          730
# 4      [Advertising, Aerospace, Automotive, Construct...          140
# ...                                                  ...          ...
# 9998                [Advertising, Marketing, Publishing]            0
# 9999   [Financial, Services, Human, Resources, IT, Ma...            2
# 10000                                                 []            0
# 10001  [Gaming, Internet, Leisure, Marketing, Telecom...            0
# 10002  [Education, IT, Internet, Technology, Telecomm...            0
#
#        nb_buyers last_active   gender            city          country
# 0           4204  17-05-2021  unknown       Sheffield   United Kingdom
# 1            880  17-05-2021  unknown  City of London   United Kingdom
# 2           1094  17-05-2021  unknown       Doncaster   United Kingdom
# 3            378  17-05-2021  unknown       Cannanore            India
# 4            100  17-05-2021  unknown  City of London   United Kingdom
# ...          ...         ...      ...             ...              ...
# 9998           0  14-02-2021  unknown       Viareggio            Italy
# 9999           1  24-04-2021  unknown          Vienna          Austria
# 10000          0  18-04-2021  unknown         Crawley   United Kingdom
# 10001          0  14-04-2021  unknown         Crawley   United Kingdom
# 10002          0  02-12-2020  unknown         Crawley   United Kingdom
#
# [10003 rows x 14 columns]

# %% [markdown]
# # Define a score for a profile
#
# **The score is based on the rating of the profile as well as the number of reviews. As the values are quite high, we use a** ``log`` **function to decrease the values but keep the growing trend.**\
# We use the following formula to avoid having issues with 0 values.
# $$score=\log(1+rating\times nb\_reviews)$$

# %%
score = np.log(1+data.rating*data.nb_reviews)

# %%
data['score'] = round(score,3)

# %%
data
# Out:
#                                      name  \
# 0                                Maria H.
# 1                         Jessica O'Neill
# 2                           Scott Anfield
# 3                        Translate Guru .
# 4      Logical Translation & Localisation
# ...                                   ...
# 9998                        Kendra Aquino
# 9999                         Maria Jussel
# 10000                      Alex Halfacree
# 10001                      Allison Gerena
# 10002                        Bilal Alagha
#
#                                  languages  \
# 0                                [English]
# 1                                [English]
# 2                                [English]
# 3                                       []
# 4      [English, Spanish, French, Italian]
# ...                                    ...
# 9998                             [English]
# 9999                     [German, English]
# 10000                            [English]
# 10001                            [English]
# 10002  [Arabic, English, Spanish, Turkish]
#
#                                              description  rating  nb_reviews  \
# 0      We are a small UK based company speciaIising i...     4.9        4745
# 1      Your blog content and website copy need to be ...     5.0        1220
# 2      An experienced and professional writer based i...     4.9        1755
# 3      Hello! Hola! Ciao! Bonjour! 你好!\r\n\r\nI do hi...     4.9         608
# 4      OFFERING A WIDE RANGE OF TRANSLATION SERVICES\...     4.9         135
# ...                                                  ...     ...         ...
# 9998   I am an ambitious professional with working ba...     0.0           0
# 9999   Founding my business in 2020 has been a real s...     5.0           3
# 10000  Hi! My name is Alex and I am a 19 year old bus...     0.0           0
# 10001  I am a professional copywriter with a BA in En...     0.0           0
# 10002  Your job's been accomplished! – You've got my ...     0.0           0
#
#        Price/hour in USD                                             skills  \
# 0                  35.21  [animation, graphics design, brand design, log...
# 1                  77.47  [editing, proofreading, transcription, academi...
# 2                  21.13  [article, product description, content writing...
# 3                  20.00  [german  english translation, arabic  english ...
# 4                  28.17  [editing, proofreading, german translation, en...
# ...                  ...                                                ...
# 9998               20.00  [editing, microsoft excel, proofreading, socia...
# 9999              145.72  [financial accounting, financial management, b...
# 10000               8.45  [administration support, data entry, business ...
# 10001              21.13  [proofreading, email marketing, product descri...
# 10002              17.00  [social media management, content writing, tec...
#
#                                       industry_expertise  nb_projects  \
# 0           [IT, Internet, Marketing, Media, Technology]         7727
# 1                                    [PR, Sales, Travel]         1546
# 2      [Advertising, Education, Marketing, Sales, Tra...         1784
# 3                                                     []          730
# 4      [Advertising, Aerospace, Automotive, Construct...          140
# ...                                                  ...          ...
# 9998                [Advertising, Marketing, Publishing]            0
# 9999   [Financial, Services, Human, Resources, IT, Ma...            2
# 10000                                                 []            0
# 10001  [Gaming, Internet, Leisure, Marketing, Telecom...            0
# 10002  [Education, IT, Internet, Technology, Telecomm...            0
#
#        nb_buyers last_active   gender            city          country   score
# 0           4204  17-05-2021  unknown       Sheffield   United Kingdom  10.054
# 1            880  17-05-2021  unknown  City of London   United Kingdom   8.716
# 2           1094  17-05-2021  unknown       Doncaster   United Kingdom   9.060
# 3            378  17-05-2021  unknown       Cannanore            India   8.000
# 4            100  17-05-2021  unknown  City of London   United Kingdom   6.496
# ...          ...         ...      ...             ...              ...     ...
# 9998           0  14-02-2021  unknown       Viareggio            Italy   0.000
# 9999           1  24-04-2021  unknown          Vienna          Austria   2.773
# 10000          0  18-04-2021  unknown         Crawley   United Kingdom   0.000
# 10001          0  14-04-2021  unknown         Crawley   United Kingdom   0.000
# 10002          0  02-12-2020  unknown         Crawley   United Kingdom   0.000
#
# [10003 rows x 15 columns]

# %%
data.to_csv('./data/full_profiles'+scraping_date+'.csv', index=False)
